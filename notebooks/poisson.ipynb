# %% [markdown]
# # Poisson and Binomial Distributions
#
# ## Binomial
#
# The binomial distribution is given by N independent trials of a Bernoulli distribution. If the Bernoulli distribution is parameterised by p where 0 <= p <= 1, then it is given by:
#
# P(X = x; p) = p^(x)(1 - p)^(1 - x)
#
# Then the binomial distribution is given by:
